# %%
import googleapiclient.discovery
import googleapiclient.errors

# %%
api_service_name = "youtube"
api_version = "v3"
#client_secrets_file = #YOUR_CLIENT_SECRET_FILE.json"
youtube = googleapiclient.discovery.build(
        api_service_name, api_version,developerKey='AIzaSyAlDte7tvxX6imead7IeGSgKXVYcrDETgI')

# %%
request = youtube.search().list(
        part="snippet",
        #forMine=True,
        maxResults=25,
        q=input('Type here'),
        type="channel"
    )
response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'Xdwmq84g2fs5eXY274yyeHhPTBA',
#  'nextPageToken': 'CBkQAA',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 629, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'dYYE_LFz9zBd2OIMqbQdQp0Xl_4',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA'},
#    'snippet': {'publishedAt': '2023-06-14T07:41:42Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'Vj Siddhu Vlogs',
#     'description': 'Hello guys! Welcome to my channel! ! My channel will take you into the details of my life and give a glimpse of what inspires me to ...',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/T9IuKawbxOW0FXuRNNUbQaZPC7VuNu-GXW4lDLCW6-kKqFaCQViXgVUpB_fzaslXU-c1W3W-=s88-c-k-c0xffffffff-no-rj-mo'},
#      'medium': {'url': 'https://yt3.ggpht.com/T9IuKawbxOW0FXuRNNUbQaZPC7VuNu-GXW4lDLCW6-kKqFaCQViXgVUpB_fzaslXU-c1W3W-=s240-c-k-c0xffffffff-no-rj-mo'},
# ...

# %%
import json
with open('a.json','w') as f:
    json.dump(response,f,indent=4)

# %%
request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id="UCJcCB-QYPIBcbKcBQOTwhiA"
)
response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '-hCs078xG2bH5lLEWJAJ-mBhgRI',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '96MzN-NJWq6yWHFzFb6qNBYgN38',
#    'id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#    'snippet': {'title': 'Vj Siddhu Vlogs',
#     'description': 'Hello guys! Welcome to my channel! !\n\nMy channel will take you into the details of my life and give a glimpse of what inspires me to do what I do. \n\nGet ready to watch my latest vlogs depicting life in detail that will make you slow down and enjoy life a little better. Subscribe to my channel and stay connected!  \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n______________________________\n\nDigital Partner - Divo\nDivo is one of the leading digital media companies in South India working with brands and content creators across genres.\n',
#     'customUrl': '@vjsiddhuvlog',
# ...

# %%
b=response['items']

# %%
c=[1,2,4]
for i in c:
    print()

# %%
b
for i in b:
    c=i['id']

# %%
c
# Out:
# 'UCJcCB-QYPIBcbKcBQOTwhiA'

# %%
i['id']
# Out:
# 'UCJcCB-QYPIBcbKcBQOTwhiA'

# %%
import pandas as pd
a=pd.json_normalize(response['items'])

# %%
pd.set_option('display.max_columns',None)

# %%
a
# Out:
#               kind                         etag                        id  \
# 0  youtube#channel  96MzN-NJWq6yWHFzFb6qNBYgN38  UCJcCB-QYPIBcbKcBQOTwhiA
#
#      snippet.title                                snippet.description  \
# 0  Vj Siddhu Vlogs  Hello guys! Welcome to my channel! !\n\nMy cha...
#
#   snippet.customUrl          snippet.publishedAt  \
# 0     @vjsiddhuvlog  2023-06-14T07:41:42.139364Z
#
#                       snippet.thumbnails.default.url  \
# 0  https://yt3.ggpht.com/T9IuKawbxOW0FXuRNNUbQaZP...
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  \
# 0                                88                                 88
#
#                        snippet.thumbnails.medium.url  \
# 0  https://yt3.ggpht.com/T9IuKawbxOW0FXuRNNUbQaZP...
#
#    snippet.thumbnails.medium.width  snippet.thumbnails.medium.height  \
# 0                              240                               240
#
#                          snippet.thumbnails.high.url  \
# ...

# %%
request = youtube.playlists().list(
        part="snippet,contentDetails",
        channelId="UCJcCB-QYPIBcbKcBQOTwhiA",
        maxResults=25
    )
response = request.execute()
print(response)
# Out:
# {'kind': 'youtube#playlistListResponse', 'etag': 'oP4stLvIYYM-Xuyu5UnLxQOjUgM', 'pageInfo': {'totalResults': 24, 'resultsPerPage': 25}, 'items': [{'kind': 'youtube#playlist', 'etag': 'bXsGmPllev4QcbNaHPPg16u8Ee8', 'id': 'PLjnNpn3gLsF_VuXLz4OAlrUM557qyl4D7', 'snippet': {'publishedAt': '2024-08-23T09:25:05Z', 'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA', 'title': '3 Million Celebration  Kovai Virundhu 🥳🔥| Vj Siddhu Vlogs', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Vj Siddhu Vlogs', 'loca
# ...

# %%
response
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'oP4stLvIYYM-Xuyu5UnLxQOjUgM',
#  'pageInfo': {'totalResults': 24, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'bXsGmPllev4QcbNaHPPg16u8Ee8',
#    'id': 'PLjnNpn3gLsF_VuXLz4OAlrUM557qyl4D7',
#    'snippet': {'publishedAt': '2024-08-23T09:25:05Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': '3 Million Celebration  Kovai Virundhu 🥳🔥| Vj Siddhu Vlogs',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/1zQA9aiXfdo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
# ...

# %%
c=[]

for i in response['items']:
    c.append(i['id'])

# %%
c[1]
# Out:
# 'PLjnNpn3gLsF9ccYQ-_sp4WETqlFhrob2K'

# %%
playlist_request =youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=c[1],
        maxResults=1
    )
playlist_s_no= playlist_request.execute()
print(playlist_s_no)
# Out:
# {'kind': 'youtube#playlistItemListResponse', 'etag': 'Dmtm_Qha2H2WTPZOK4Pm2z9u-s8', 'nextPageToken': 'EAAajgFQVDpDQUVpRURrME9UVkVSa1EzT0VRek5Ua3dORE1vQVVpRTk0ZjV2NFdJQTFBQldrVWlRMmxLVVZSSGNIVlVia0oxVFRKa1RXTXdXVFZaTWs1YVZWTXhabU16UVRCV01GWlZZMWQ0UjJGSVNuWlpha3BNUldkM1NUTktNbGQwWjFsUmIwMWxlbkpSUlNJ', 'items': [{'kind': 'youtube#playlistItem', 'etag': 'dsdEtk7lX1TXVr_IxMp8GoKaPyQ', 'id': 'UExqbk5wbjNnTHNGOWNjWVEtX3NwNFdFVHFsRmhyb2IySy5GNjNDRDREMDQxOThCMDQ2', 'snippet': {'publishedAt': '2024-08-21T06:53:15Z', 'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA', 'title': 'மாட்டிக்கிட்டான் டா Sabbu 😂 | Arupadai Trip Ep-9  | Vj Siddhu Vlogs', 'description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #arupadaiveedu #arupadaitrip #vjsiddhu #settaisheriff #harshathkhan #camsoori #episode9\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInst
# ...

# %%
playlist_s_no
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'Dmtm_Qha2H2WTPZOK4Pm2z9u-s8',
#  'nextPageToken': 'EAAajgFQVDpDQUVpRURrME9UVkVSa1EzT0VRek5Ua3dORE1vQVVpRTk0ZjV2NFdJQTFBQldrVWlRMmxLVVZSSGNIVlVia0oxVFRKa1RXTXdXVFZaTWs1YVZWTXhabU16UVRCV01GWlZZMWQ0UjJGSVNuWlpha3BNUldkM1NUTktNbGQwWjFsUmIwMWxlbkpSUlNJ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'dsdEtk7lX1TXVr_IxMp8GoKaPyQ',
#    'id': 'UExqbk5wbjNnTHNGOWNjWVEtX3NwNFdFVHFsRmhyb2IySy5GNjNDRDREMDQxOThCMDQ2',
#    'snippet': {'publishedAt': '2024-08-21T06:53:15Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'மாட்டிக்கிட்டான் டா Sabbu 😂 | Arupadai Trip Ep-9  | Vj Siddhu Vlogs',
# ...

# %%
videoid=[]

for i in playlist_s_no['items']:
    videoid.append(i['contentDetails']['videoId'])

# %%
videoid
# Out:
# ['Irtf3Nmmxr0']

# %%
videoid = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=videoid[0]
    )
r= videoid.execute()

print(r)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'N4fEr83kOUSN9O3irPZrrjEzsyQ', 'items': [{'kind': 'youtube#video', 'etag': 'r3OplP_MnfsVfLtoYVaobxuWshY', 'id': 'Irtf3Nmmxr0', 'snippet': {'publishedAt': '2024-08-21T09:30:24Z', 'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA', 'title': 'மாட்டிக்கிட்டான் டா Sabbu 😂 | Arupadai Trip Ep-9  | Vj Siddhu Vlogs', 'description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #arupadaiveedu #arupadaitrip #vjsiddhu #settaisheriff #harshathkhan #camsoori #episode9\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\n
# ...

# %%
r
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'N4fEr83kOUSN9O3irPZrrjEzsyQ',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'r3OplP_MnfsVfLtoYVaobxuWshY',
#    'id': 'Irtf3Nmmxr0',
#    'snippet': {'publishedAt': '2024-08-21T09:30:24Z',
#     'channelId': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#     'title': 'மாட்டிக்கிட்டான் டா Sabbu 😂 | Arupadai Trip Ep-9  | Vj Siddhu Vlogs',
# ...

# %%
pd.json_normalize(r['items'])
# Out:
#             kind                         etag           id  \
# 0  youtube#video  r3OplP_MnfsVfLtoYVaobxuWshY  Irtf3Nmmxr0
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2024-08-21T09:30:24Z  UCJcCB-QYPIBcbKcBQOTwhiA
#
#                                        snippet.title  \
# 0  மாட்டிக்கிட்டான் டா Sabbu 😂 | Arupadai Trip Ep...
#
#                                  snippet.description  \
# 0  For Business inquiries please contact us :7200...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/Irtf3Nmmxr0/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  \
# 0                               120                                 90
#
#                       snippet.thumbnails.medium.url  \
# 0  https://i.ytimg.com/vi/Irtf3Nmmxr0/mqdefault.jpg
#
#    snippet.thumbnails.medium.width  snippet.thumbnails.medium.height  \
# 0                              320                               180
#
# ...

# %%
with open('scrap.json','w')as f:
    json.dump(r,f,indent=4)

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = 'AIzaSyAlDte7tvxX6imead7IeGSgKXVYcrDETgI'  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
    "UCB3-py860zX_nHCfnwE0GrA",
    "UCGoiclUrJhOA14waY85_D5w",
    "UCP0f9FXZ4g-MxAqSUreHpCw",
    "UCYd0us2OtW4d4-1cfpT2ktw",
    "UCWI1AJmkMm_sbTX_Ps8gQAw"
] 


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('data.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")
# Out:
# Playlist IDs: ['PLw79IvuHGRQDaH7OvBNfpeO1kelPq84eg', 'PLw79IvuHGRQABdw6ykxtetlf8HPlMKRHT', 'PLw79IvuHGRQDcF-6NH-BlwhtHFGyxC2dC', 'PLw79IvuHGRQCIRRiKwZF4V6BNxEklvpeX', 'PLw79IvuHGRQC7TZit4tcl7Mkxrhui-RHh', 'PLw79IvuHGRQB1alFkK6KAZviGuaW9ws72', 'PLw79IvuHGRQDV3x1imI2pxO0KDpWg5SPb', 'PLw79IvuHGRQDnNQtKwR_EmWcI8sYF5PnB', 'PLw79IvuHGRQCse9_F00Md5tNRbVopE0IB', 'PLw79IvuHGRQB5guWpH71kTZviOqnrz3Mh', 'PLw79IvuHGRQAfz5vnN04EE2S1i1wiOqdQ', 'PLyQ4wTUw439AHLQ_d-ffF6mzsQDwT6-q_', 'PLyQ4wTUw439BgcnVZR1jZ9Qm66LnlcBSL', 'PLyQ4wTUw439Abcl3hQpKJ-V9OpyxB5crI', 'PLyQ4wTUw439AvaORXKaFehzUoHZo7kJlE', 'PLyQ4wTUw439Co-SAsUnuPjhJiMcRxuiKW', 'PLyQ4wTUw439BLrCwhs1ekigrQNOW9QIHQ', 'PLyQ4wTUw439CtFs4fjMBdzVXvzKkC0O97', 'PLyQ4wTUw439AQMx4fGuzs3QSkFDjFYAIU', 'PLyQ4wTUw439Ct_HTCp6TqonlmaJ-v0Fi_', 'PLyQ4wTUw439CIWoBvDrKeP_Ehq9Eyc--k', 'PLavKQiluDk_N93S_29Fe6q7zNEF3NhRns', 'PLavKQiluDk_NViGJtyjEyDpPZU9ihgGdR', 'PLavKQiluDk_O5n0937CSU600vlBnFHNqj', 'PLavKQiluDk_M7UXIUm_HtxvC0r4LOFYCr', 'PLavKQiluDk_Mx7A0X3YWC7WDKqe1JuD
# ...

# %%
from googleapiclient.discovery import build
service_name = "youtube"
version = "v3"
api_key = 'AIzaSyAlDte7tvxX6imead7IeGSgKXVYcrDETgI'  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)
channel_name = input('Enter your channel name: ')


request = youtube.search().list(
    part="snippet",
    maxResults=25,
    q="fun",
    type="video"
)
response = request.execute()
a=request.execute()
a
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'SW59wzcVvetMcnZc24mwaF_oseQ',
#  'nextPageToken': 'CBkQAA',
#  'regionCode': 'IN',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'mrRDW7ZUkFlYY4GFHhc5nFUU7WE',
#    'id': {'kind': 'youtube#video', 'videoId': 'Sv6dMFF_yts'},
#    'snippet': {'publishedAt': '2011-12-28T06:24:43Z',
#     'channelId': 'UClVrJwcIy7saPcGc1nct80A',
#     'title': 'Fun.: We Are Young ft. Janelle Monáe [OFFICIAL VIDEO]',
#     'description': "Fun.'s music video for 'We Are Young' from the album, Some Nights - available now on Fueled By Ramen. Celebrate the 10th ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Sv6dMFF_yts/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Sv6dMFF_yts/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
with open ("k.json","w") as f:
    json.dump(playlist_response,f,indent=4)

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = ''  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
    'UCkw4JCwteGrDHIsyIIKo4tQ',
'UCh9nVJoWXmFb7sLApWGcLPQ',
'UC8butISFwT-Wl7EV0hUK0BQ',
'UCJHs6RO1CSM85e8jIMmCySw',
'UC59K-uG2A5ogwIrHw4bmlEg',
'UCNU_lfiiWBdtULKOw6X0Dig'
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"error occured")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('educational.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")
# Out:
# Playlist IDs: ['PL9ooVrP1hQOFIOOkGN2gbjvse8jcz-mux', 'PL9ooVrP1hQOEo4_b-LZY76Cb6ewCax7li', 'PL9ooVrP1hQOE5dmqWrYQqQTX-FFyfYdLf', 'PL9ooVrP1hQOFgN0YdrcYvpF_YeJx8a7Lu', 'PL9ooVrP1hQOEzTT5zaViH2djLoys7S9Cl', 'PL9ooVrP1hQOFSLYevihGa18dO-xfojJsT', 'PL9ooVrP1hQOHiYxh2pGcoz3TUd8ETnB5E', 'PL9ooVrP1hQOEXFaGm5Igdp6VDtSPYPlER', 'PL9ooVrP1hQOEzxpOfu16w0xo3TZT1vYhk', 'PL9ooVrP1hQOHjUeBB2NLCR4ogEXic36uI', 'PL9ooVrP1hQOESasdNOGBSGg1igKbl6c1q', 'PL9ooVrP1hQOGpbAJW6fvGa68Yb1C9Ytkt', 'PL9ooVrP1hQOEHWBYRV3XKDa-dTrl_8yvP', 'PL9ooVrP1hQOHPt-qWXdqElNXrNsOw_yWd', 'PL9ooVrP1hQOH-yEvwMdMmXbZT1CFx5Bv_', 'PL9ooVrP1hQOGMkx8a9vEgzNopaqkTkewc', 'PL9ooVrP1hQOG6DQnOD6ujdCEchaqADfCU', 'PL9ooVrP1hQOH-nMMFeSG-DFwyATtUg4YA', 'PL9ooVrP1hQOGdNkEnM8LXUMV5W7kGSNbu', 'PL9ooVrP1hQOFtZ5oAAeOgi_nH-txMcDMu', 'PL9ooVrP1hQOG5HyvfIKr-gWRpPCTZnFvq', 'PL9ooVrP1hQOHKe6_fmhxxjfg8iJ-SeBZ-', 'PL9ooVrP1hQOFeNaSroVp1KJyTiUcvBl0E', 'PL9ooVrP1hQOE4KoZLUP4LgBwFH2IJCQs6', 'PL9ooVrP1hQOEe9EN119lMdwcBxcrBI1D3', 'PL9ooVrP1hQOGOjbgkKOZeafb6ewsAdo
# ...

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = ""  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
   "UC_WKb6N9iTGc77hxwXLDrbA",
"UCTl3QQTvqHFjurroKxexy2Q",
"UC14UlmYlSNiQCBe9Eookf_A",
"UCWV3obpZVGgJ3j9FVhEjF2Q",
"UCl23mvQ3321L7zO6JyzhVmg"
"UC2J_VKrAzOEJuQvFFtj3KUw"
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('sports.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")
# Out:
# An error occurred while fetching playlists: <HttpError 404 when requesting https://youtube.googleapis.com/youtube/v3/playlists?part=snippet%2CcontentDetails&channelId=UCl23mvQ3321L7zO6JyzhVmgUC2J_VKrAzOEJuQvFFtj3KUw&maxResults=100&key=AIzaSyBesXkNqT3lursjeN3PbJbeqMDewgvJlpI&alt=json returned "Channel not found.". Details: "[{'message': 'Channel not found.', 'domain': 'youtube.playlist', 'reason': 'channelNotFound', 'location': 'channelId', 'locationType': 'parameter'}]">
# ...

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = ""  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
   "UC_WKb6N9iTGc77hxwXLDrbA",
"UCTl3QQTvqHFjurroKxexy2Q",
"UC14UlmYlSNiQCBe9Eookf_A",
"UCWV3obpZVGgJ3j9FVhEjF2Q",
"UCl23mvQ3321L7zO6JyzhVmg"
"UC2J_VKrAzOEJuQvFFtj3KUw"
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('sports.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")

# %%
a=[]
for i in video_details:
    if 'items' in i:
        a.extend(i['items'])

# %%
import pandas as pd
c=pd.json_normalize(a)

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = ""  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
   "UC_WKb6N9iTGc77hxwXLDrbA",
"UCTl3QQTvqHFjurroKxexy2Q",
"UC14UlmYlSNiQCBe9Eookf_A",
"UCWV3obpZVGgJ3j9FVhEjF2Q",
"UCl23mvQ3321L7zO6JyzhVmg"
"UC2J_VKrAzOEJuQvFFtj3KUw"
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('sports.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = ""  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
   "UC_WKb6N9iTGc77hxwXLDrbA",
"UCTl3QQTvqHFjurroKxexy2Q",
"UC14UlmYlSNiQCBe9Eookf_A",
"UCWV3obpZVGgJ3j9FVhEjF2Q",
"UCl23mvQ3321L7zO6JyzhVmg"
"UC2J_VKrAzOEJuQvFFtj3KUw"
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('sports.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = "AIzaSyBesXkNqT3lursjeN3PbJbeqMDewgvJlpI"  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
   "UC_WKb6N9iTGc77hxwXLDrbA",
"UCTl3QQTvqHFjurroKxexy2Q",
"UC14UlmYlSNiQCBe9Eookf_A",
"UCWV3obpZVGgJ3j9FVhEjF2Q",
"UCl23mvQ3321L7zO6JyzhVmg"
"UC2J_VKrAzOEJuQvFFtj3KUw"
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('sports.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")

# %%
with open('educational.json', 'r') as file:
    video_details = json.load(file)

# %%
a=[]
for i in video_details:
    if 'items' in i:
        a.extend(i['items'])

# %%
b=pd.json_normalize(a)

# %%
def changefunction(x):
    if x is None:
        return None
    if isinstance(x, list):
        return "".join(x)
    print(f"Unexpected type: {type(x)}, value: {x}")  # Debugging output
    return x


# Assuming 'b' is your DataFrame and 'snippet.tags' is a list of tags
b['snippet.tags'] = b['snippet.tags'].apply(changefunction)
# Out:
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# Unexpected type: <class 'float'>, value: nan
# ...

# %% [markdown]
# "UCupvZG-5ko_eiXAupbDfxWw",
# "UCYPvAwZP8pZhSMW8qs7cVCw",
# "UC16niRr50-MSBwiO3YDb3RA",
# "UCz8QaiQxApLq8sLNcszYyJw",
# "UCZFMm1mMw0F81Z37aaEzTUA"

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = "" 
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids = [
  "UCupvZG-5ko_eiXAupbDfxWw",
"UCYPvAwZP8pZhSMW8qs7cVCw",
"UC16niRr50-MSBwiO3YDb3RA",
"UCz8QaiQxApLq8sLNcszYyJw",
"UCZFMm1mMw0F81Z37aaEzTUA"
]


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('news.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")
# Out:
# Playlist IDs: ['PL6XRrncXkMaWUNJen6v0k1bbakEKbxadT', 'PL6XRrncXkMaW0iwMJL7j1S7v5pzKgIHRk', 'PL6XRrncXkMaUAV-OmpYhlUniVSClehqq-', 'PL6XRrncXkMaWWFyjMtzWWSeOocFr-N_3s', 'PL6XRrncXkMaUNhifXWtS3gZtctnZpUZPw', 'PL6XRrncXkMaWHdqYro173ihPrqS_mdafT', 'PL6XRrncXkMaVg2Xd4g2icI4M36-eAozy0', 'PL6XRrncXkMaU55GiCvv416NR2qBD_xbmf', 'PL6XRrncXkMaW9CdmnrS4NVWKavtqRO8hT', 'PL6XRrncXkMaVXAutoJ8D2RDKAz_XufaFm', 'PL6XRrncXkMaXpv1ZA2l3jwnhbajEEROUe', 'PL6XRrncXkMaW8rqNW6ddCsT6SEosWF4W2', 'PL6XRrncXkMaWdcHpyKh3fcAsf6aDOQOnM', 'PL6XRrncXkMaWIJy9reBfgOQkPMfPt-KNl', 'PL6XRrncXkMaWuCgRkfO9o_B2odKQxTBI4', 'PL6XRrncXkMaVKJiRkKEDLbOQ7kaAIBR1t', 'PL6XRrncXkMaUJEgNM9QbfAulA2u684ON0', 'PL6XRrncXkMaVcAyYoXByXNtFJ1nxRg6J7', 'PL6XRrncXkMaUZb-dIuCXa1csnpyVvoErY', 'PL6XRrncXkMaWmz7BIhhVBwL6kG3psLUuw', 'PL6XRrncXkMaU4yqgPbhqblbXacFO1TjXY', 'PL6XRrncXkMaWsHRkoIp3Q9WcQb4zhR6_t', 'PL6XRrncXkMaV5_rYaLzWHhYke_03L4ILC', 'PL6XRrncXkMaXedndSn9yRspW6X8YZ8HQ1', 'PL6XRrncXkMaUFpKf-Qw2DYq6H7hGmDxvu', 'PL6XRrncXkMaUeGtwPgP7xJXdCMAlQhs
# ...

# %%
def channelid():
    return[
"UCXw1ddyrUmib3zmCmvSI1ow",
"UCj4KP216972cPp2w_BAHy8g",
"UC8Y-jrV8oR3s2Ix4viDkZtA",
"UCwiTOchWeKjrJZw7S1H__1g",
"UCIEv3lZ_tNXHzL3ox-_uUGQ"]

# %%
from googleapiclient.discovery import build
import pandas as pd
import json

service_name = "youtube"
version = "v3"
api_key = "AIzaSyBesXkNqT3lursjeN3PbJbeqMDewgvJlpI"  # Replace with your actual API key
youtube = build(service_name, version, developerKey=api_key)

video_details = []
playlist_ids = []

channel_ids=channelid()


for channel_id in channel_ids:
    try:
        playlist_request = youtube.playlists().list(
            part="snippet,contentDetails",
            channelId=channel_id,
            maxResults=100
        )
        playlist_response = playlist_request.execute()

        for item in playlist_response['items']:
            if 'id' in item:
                playlist_ids.append(item['id'])

    except Exception as e:
        print(f"An error occurred while fetching playlists: {e}")

print(f"Playlist IDs: {playlist_ids}")


for playlist_id in playlist_ids:
    next_page_token = None
    video_count = 0
    while True:
        try:
            playlist_items_request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                maxResults=2,  
                playlistId=playlist_id,
                pageToken=next_page_token
            )
            playlist_items_response = playlist_items_request.execute()

            for item in playlist_items_response['items']:
                if video_count < 2:  
                    video_id = item['contentDetails']['videoId']
                    video_details_request = youtube.videos().list(
                        part="snippet,contentDetails,statistics",
                        id=video_id
                    )
                    video_details_response = video_details_request.execute()
                    
                    
                    video_details.append(video_details_response)
                    video_count += 1

            next_page_token = playlist_items_response.get('nextPageToken')
            if not next_page_token or video_count >= 2:
                break

        except Exception as e:
            print(f"An error occurred while fetching video details: {e}")
            break


with open('food.json', 'w') as file:
    json.dump(video_details, file, indent=4)

print("Video details have been saved to data.json")
# Out:
# Playlist IDs: ['PLMa-Hn9ToHjzFj2egHLLnNh5kZoJr1Btj', 'PLMa-Hn9ToHjyCGiAlucJvUXONOUStTIQH', 'PLMa-Hn9ToHjxthr24TRl-XWAIzp4FaA6O', 'PLpbCMGDjn19jGU2kF8WZCj2xIGUOMkOC6', 'PLpbCMGDjn19jepWEL9sHHjGyGp3eRYm0z', 'PLpbCMGDjn19gTBBaJfXp9psJBpOlv5ft5', 'PLpbCMGDjn19i51fEVx6w_KOPiqUleUxdJ', 'PLpbCMGDjn19iuUyQ8MGdiW3LIq2dXw6s6', 'PLpbCMGDjn19hdKzqNO9rxaDZyzZdY2zrD', 'PLpbCMGDjn19jrQQuf52JX_g2Uklqbj1Or', 'PLpbCMGDjn19gq5GSYdWDoM1vVpqJ44JHd', 'PLpfv1AIjenVMtPpgOaMeJKIJIPNuq8eXC', 'PLpfv1AIjenVOwfOYodb0RWlOyvjnWafGR', 'PLpfv1AIjenVNn3eVqg6NWavQ873b3xZOe', 'PLpfv1AIjenVNjpx69BRuH9ZbMcw7QVNKD', 'PLpfv1AIjenVMk4WOsb5pQgRUjVxQy5oEd', 'PLpfv1AIjenVNdjrQuhlNxjkUoxOQQ5wM6', 'PLpfv1AIjenVMgiE7ZjJ0DSTaAdDZbyxZ4', 'PLpfv1AIjenVMEJ8xKqttU_gBHPmSHQYOE', 'PLpfv1AIjenVN9qdE9PIhZIDFfi3C6XjST', 'PLpfv1AIjenVOu4V5UCYa9t7QkSv6Kiggh', 'PLpfv1AIjenVME-UFJuzEArQZXPh5qj3Eh', 'PLpfv1AIjenVMTDQlx2S5L7VQdLFmAliVv', 'PLpfv1AIjenVNUm7wAmFOgr-Fz-zehgXU7', 'PLpfv1AIjenVOKtwTgJE9LQEQIZgVARxzn', 'PLpfv1AIjenVPcAyGtOS6QCNTMg7a__t
# ...

# %%
next_page_token = playlist_items_response.get('nextPageToken')
next_page_token
# Out:
# 'EAAaclBUOkNBSWlFRGMwTVRoQ016WTJPVU5HTkVJM1F6RW9BVWl6cU1hNTE4V0dBMUFCV2pBaVEyaEtVVlJFV1ROU1JHY3hVVlJKTWs1RlZUQlNSRlY1VGxSVlUwUkJhWG90TkU5NlFtaEROREJ5WVZkQmR5SQ'

# %%
with open('food.json','r') as file:
    food=json.load(file)

# %%
a=[]
for i in food:
    if "items" in i:
        a.extend(i['items'])

# %%
k=pd.json_normalize(a)

# %%
k['snippet.tags']=k['snippet.tags'].apply(lambda x:"".join(x) if isinstance(x,list) else x)

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Automatically adjust width
pd.set_option('display.max_colwidth', None)

# %%
k['snippet.tags']=k['snippet.tags'].dropna()

# %%
k['snippet.tags']
# Out:
# 0                                                                                                                                                                                                                                                                                                 besteverfoodreviewshowbefrsstreetfoodfoodreviewfoodbloggerfoodandtravelyummyfoodienomnomtravelsonnysidesonnyfoodgasmfoodpornfoodandwineseafoodfooddelicioustravelchannel
# 1                                                                                                                                                                                                                                                                                                 besteverfoodreviewshowbefrsstreetfoodfoodreviewfoodbloggerfoodandtravelyummyfoodienomnomtravelsonnysidesonnyfoodgasmfoodpornfoodandwineseafoodfooddelicioustravelchannel
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
c=LabelEncoder()
tags = k['snippet.tags'].values.reshape(-1, 1)
p=c.fit_transform(tags)
# Out:
# e:\guvi final\.venv\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(p)
# Out:
# [130 130 208 208 208 208 193 204 197 203 201 199 198 196 202 206 195 207
#  194 200 205 192 208 208 208 208 131 208   3   2 148 149 123 122   1   0
#  141 138 127 128 167 168 137 134 144 152 133 132 151 154 153 150 178 179
#  184 185 160 155 177 135 158 159 157 156 183 182 143 142 146 161 165 164
#  187  56 169 166 176 126 136 162 129 147   4 170 171 124 125 145 172 173
#    5 174 180 181 163 175 139 140 131 188 101  68  57  57  57  69  57  57
#   79  62  57  57 121  71  57  57  57  57  57  57  57  66  57  57  57 100
#   76  91  57  57  70  65 114  81 119  74  73 117  85  60  96  92  63  64
#   82  72  88  90  84 111 191  80  75  57  57  61  94 110  89  86  99  59
#  107 106 114 113  57  57   6 120  95  97  57  66 102 116  87  58  83 115
#  104 105  98 118 112 108 103  77  57  78  67  57  93 109  57  57  44  44
#   44  44  44  44  44  44  44  44  32  33  50  50  36  35  38  42  39  45
#   34  37  44  44  41  40 190 189  44  44  47  55  49  54  53   9 208 186
# ...

# %%
print(p)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 266 stored elements and shape (266, 209)>
#   Coords	Values
#   (0, 130)	1.0
#   (1, 130)	1.0
#   (2, 208)	1.0
#   (3, 208)	1.0
#   (4, 208)	1.0
#   (5, 208)	1.0
#   (6, 193)	1.0
#   (7, 204)	1.0
#   (8, 197)	1.0
#   (9, 203)	1.0
#   (10, 201)	1.0
#   (11, 199)	1.0
#   (12, 198)	1.0
#   (13, 196)	1.0
#   (14, 202)	1.0
#   (15, 206)	1.0
#   (16, 195)	1.0
#   (17, 207)	1.0
#   (18, 194)	1.0
#   (19, 200)	1.0
#   (20, 205)	1.0
#   (21, 192)	1.0
#   (22, 208)	1.0
#   (23, 208)	1.0
#   (24, 208)	1.0
#   :	:
#   (241, 10)	1.0
#   (242, 8)	1.0
#   (243, 8)	1.0
#   (244, 19)	1.0
#   (245, 20)	1.0
#   (246, 26)	1.0
#   (247, 9)	1.0
#   (248, 22)	1.0
#   (249, 21)	1.0
#   (250, 13)	1.0
#   (251, 7)	1.0
#   (252, 30)	1.0
#   (253, 29)	1.0
#   (254, 24)	1.0
#   (255, 27)	1.0
#   (256, 25)	1.0
#   (257, 23)	1.0
#   (258, 31)	1.0
#   (259, 28)	1.0
#   (260, 52)	1.0
#   (261, 46)	1.0
#   (262, 18)	1.0
#   (263, 16)	1.0
# ...

# %%
with open("food.txt", "w", encoding="utf-8") as x:
    for tag in k['snippet.tags']:
        if isinstance(tag, str): 
            x.write(tag + "\n")
        else:
            print(f"Skipping non-string tag: {tag}")
# Out:
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan
# Skipping non-string tag: nan

# %%
import json
with open('food.json','r') as file:
    food=json.load(file)

# %%
a=[]
for i in food:
    if "items" in i:
        a.extend(i['items'])

# %%
import pandas as pd
b=pd.json_normalize(a)

# %%
import numpy as np

# %%
 b['snippet.tags']=b['snippet.tags'].apply(lambda x:"".join(x) if isinstance(x,list) else None)

# %%
b=b.dropna()

# %%
x = b['snippet.tags'].dropna().to_numpy().reshape(-1, 1)

# %%
x
# Out:
# array([['besteverfoodreviewshowbefrsstreetfoodfoodreviewfoodbloggerfoodandtravelyummyfoodienomnomtravelsonnysidesonnyfoodgasmfoodpornfoodandwineseafoodfooddelicioustravelchannel'],
#        ['besteverfoodreviewshowbefrsstreetfoodfoodreviewfoodbloggerfoodandtravelyummyfoodienomnomtravelsonnysidesonnyfoodgasmfoodpornfoodandwineseafoodfooddelicioustravelchannel'],
#        ['wildernesswilderness cookingrecipedishwildbeefbeef recipebeef tailtailtail beefbeef tail recipebeef tail on ovenoxtail recipeoxtailoxtail stewbeef stewbeef stew recipehow to cookwild cookingcooking videosvillage cookingcampfire cookingжизнь в деревнеrelaxing videocookingmeatnaturebeef recipesrelaxing video asmroutdoor cookingcountry life blogcountry lifecooking vlogmeat recipedinnerrelaxing video nature'],
# ...

# %%
x.to_numpy().reshape(-1,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 x.to_numpy().reshape(-1,1)
#
# AttributeError: 'function' object has no attribute 'to_numpy'

# %%
import pickle
import streamlit as st
import numpy as np
import pandas as pd
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
import mysql.connector
conn = mysql.connector.connect(

    host="localhost",

    user="root",

    port="3306",

    password="seenu2218",

    database="finalproject"

)

table_name='youtube'
database="finalproject"
cursor = conn.cursor()

writer = cursor 

query = "SELECT * FROM youtube"
cursor.execute(query)
view=cursor.fetchall()

query2 =f"SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = '{table_name}' AND TABLE_SCHEMA = '{database}' ORDER BY ORDINAL_POSITION"
cursor.execute(query2)
a=cursor.fetchall()
flat_list = [item[0] for item in a]
final=pd.DataFrame(view)
final.columns=flat_list

# %%
final
# Out:
#                                           snippet.title  \
# 0     Asia's Shocking Tarantula Soup! Rare Village F...
# 1        DANGEROUS Live Fish Eating in Vietnam Village!
# 2     Juicy BEEF TAILS Cooked in a Oven on Fire-wood...
# 3     The famous recipe for beef head HASH! Soup tha...
# 4     I made a Water Skewer from Mushrooms! Crispy C...
# ...                                                 ...
# 1547  Now Developing Your Deep Learning Application ...
# 1548  Tutorial 1-Transformer And Bert Implementation...
# 1549  Tutorial 2- Fine Tuning Pretrained Model On Cu...
# 1550  Introduction To Nvidia Rapids- cuDF,cuML Libra...
# 1551  Training Machine Learning Algorithms In GPU Us...
#
#                       snippet.thumbnails.default.url  \
# 0     https://i.ytimg.com/vi/y37OSdSCtak/default.jpg
# 1     https://i.ytimg.com/vi/4FCsZHE_CmY/default.jpg
# 2     https://i.ytimg.com/vi/SHQVaw69Nxk/default.jpg
# 3     https://i.ytimg.com/vi/aOi6o7VHlvU/default.jpg
# ...

# %%
final["statistics.viewCount"]=final["statistics.viewCount"].fillna(0)
final["statistics.viewCount"]=final["statistics.viewCount"].astype(int)

# %%
final2=final.sort_values(by="statistics.viewCount",ascending=False)

# %%
final2
# Out:
#                                           snippet.title  \
# 217     Gordon Ramsay Catches King Crab | Gordon Ramsay
# 868   If Cute Babies Competed in the Winter Games | ...
# 1327  Learn Python - Full Course for Beginners [Tuto...
# 219   How To Master 5 Basic Cooking Skills | Gordon ...
# 14    7 HOURS OF ROASTING A HUGE THIGH OF BEEF IN A ...
# ...                                                 ...
# 1500  Machine Learning Series- Universe of Data Scie...
# 1381                                Docker Introduction
# 1382               What problem we are trying to solve?
# 1385                                Git Version Control
# 1386                                          Git Setup
#
#                       snippet.thumbnails.default.url snippet.channelTitle  \
# 217   https://i.ytimg.com/vi/p6ff-ShY5Bw/default.jpg        Gordon Ramsay
# 868   https://i.ytimg.com/vi/0pJU3jm0zkI/default.jpg             Olympics
# ...
